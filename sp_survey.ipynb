# %%
# Clone the repository
# !git clone https://github.com/Sijie-Yang/Streetscape-Perception-Survey.git
# !cd Streetscape-Perception-Survey
# Out:
# Cloning into 'Streetscape-Perception-Survey'...
# remote: Enumerating objects: 874, done.
# remote: Counting objects: 100% (140/140), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 874 (delta 75), reused 80 (delta 44), pack-reused 734 (from 1)
# Receiving objects: 100% (874/874), 27.38 MiB | 15.20 MiB/s, done.
# Resolving deltas: 100% (505/505), done.
# zsh:1: command not found: npm
# zsh:1: command not found: npm

# %%
cd /Users/zicheng/Documents/research/prachi/Streetscape-Perception-Survey
# Out:
# /Users/zicheng/Documents/research/prachi/Streetscape-Perception-Survey

# %%
# Install dependencies
pip install -r requirements.txt
# Out:
# zsh:1: command not found: npm

# %%
# Install dependencies
# !npm install
# Out:
# zsh:1: command not found: npm

# %%
# Move into the project directory for subsequent commands
# %cd Streetscape-Perception-Survey

# Install dependencies
npm install

# Start both frontend and backend
npm run dev
# Out:
# /Users/zicheng/Documents/research/prachi/Streetscape-Perception-Survey
# zsh:1: command not found: npm
# /Users/zicheng/Library/Python/3.9/lib/python/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# zsh:1: command not found: npm
